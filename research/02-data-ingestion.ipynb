# %%
import requests
import json
from mlProject.utils.ura_token import ura_token
from pandas import json_normalize
import pandas as pd
import psycopg2
import uuid
import pandas.io.sql as psql

# %%
from datetime import datetime
from typing import List, Optional
#from pydantic import BaseModel
import json
import psycopg2.extras

# call it in any place of your program
# before working with UUID objects in PostgreSQL
psycopg2.extras.register_uuid()
# Out:
# <psycopg2._psycopg.type 'UUID' at 0x7f8921766890>

# %%
def get_dataframe_from_sql(table_name: str, conn_params: dict):
    connection = psycopg2.connect(**conn_params)
    cursor = connection.cursor()
    df = psql.read_sql(f"Select * from {table_name}", connection)
    return df

# %%
# Connect to PostgreSQL
conn_params = {
    "host":"localhost",
    "database":"mydatabase",
    "user":"myuser",
    "password":"mypassword"

}

table_name = "propertypricetable"
df_fetch = get_dataframe_from_sql(table_name, conn_params)
df_fetch.head()
# Out:
# /var/folders/rj/64nmqpkj7j1dz_vk_9vdrqfw0000gn/T/ipykernel_39046/4176278397.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = psql.read_sql(f"Select * from {table_name}", connection)
#                                      id   area floor_range  no_of_units  \
# 0  bd8e964b-8b01-45ca-9cd5-d5810b9588d4  159.3           -            1
# 1  54d728f7-df61-42fc-ab22-f7ef08bbe7dd  186.0           -            1
# 2  b5190668-75e4-49e5-9fc4-81b504d8d35a  257.0           -            1
# 3  d46fe197-3c71-4278-83ed-51bb2816db8e  524.3           -            1
# 4  a825db95-5239-4bd9-8e19-f21bb265d42b  308.0           -            1
#
#   contract_date type_of_sale      price   property_type district type_of_area  \
# 0    2020-03-01            3  2630000.0         Terrace       05         Land
# 1    2021-03-01            3  1880000.0  Strata Terrace       05       Strata
# 2    2022-05-01            3  4600000.0         Terrace       05         Land
# 3    2020-02-01            3  5500000.0   Semi-detached       05         Land
# 4    2021-09-01            3  5200000.0   Semi-detached       05         Land
#
#      tenure  nett_price                     project             street  \
# 0  Freehold         NaN  LANDED HOUSING DEVELOPMENT  NEO PEE TECK LANE
# 1  Freehold         NaN  LANDED HOUSING DEVELOPMENT  NEO PEE TECK LANE
# 2  Freehold         NaN  LANDED HOUSING DEVELOPMENT  NEO PEE TECK LANE
# 3  Freehold         NaN  LANDED HOUSING DEVELOPMENT       ZEHNDER ROAD
# 4  Freehold         NaN  LANDED HOUSING DEVELOPMENT       ZEHNDER ROAD
#
#   market_segment             x             y
# 0            RCR  20914.198897  30589.107079
# 1            RCR  20914.198897  30589.107079
# 2            RCR  20914.198897  30589.107079
# 3            RCR           NaN           NaN
# 4            RCR           NaN           NaN

# %% [markdown]
# connection = psycopg2.connect(**conn_params)
# cursor = connection.cursor()
# cursor.execute("""SELECT table_name FROM information_schema.tables
#        WHERE table_schema = 'public'""")
# for table in cursor.fetchall():
#     print(table)
# cursor.close()
# connection.close()

# %%
df_ec = df_fetch.loc[(df_fetch['property_type']=='Executive Condominium')&(df_fetch['type_of_sale']=='3')].sort_values(by=['contract_date'])

# %%
df_ec.head(2)
# Out:
#                                           id   area floor_range  no_of_units  \
# 126465  70233109-b115-470a-8598-c6ac7fac4400  120.0       11-15            1
# 124157  836f7655-2f22-4c9f-8461-e09aa66dbd46   90.0       11-15            1
#
#        contract_date type_of_sale     price          property_type district  \
# 126465    2019-09-01            3  853000.0  Executive Condominium       23
# 124157    2019-09-01            3  875000.0  Executive Condominium       23
#
#        type_of_area                             tenure  nett_price  \
# 126465       Strata  99 yrs lease commencing from 1997         NaN
# 124157       Strata  99 yrs lease commencing from 2011         NaN
#
#                    project                 street market_segment            x  \
# 126465       YEW MEI GREEN  CHOA CHU KANG NORTH 6            OCR  18819.03588
# 124157  BLOSSOM RESIDENCES             SEGAR ROAD            OCR  20983.51444
#
#                   y
# 126465  41984.19449
# 124157  41310.75604

# %%
df_ec.tail(2)
# Out:
#                                          id   area floor_range  no_of_units  \
# 99951  edf3f4fe-d245-46f0-b823-31df5c118311   99.0       11-15            1
# 99769  242083df-6b08-4c08-83f6-5a1cfd6345f8  127.0       11-15            1
#
#       contract_date type_of_sale      price          property_type district  \
# 99951    2024-08-01            3  1780000.0  Executive Condominium       19
# 99769    2024-08-01            3  1530000.0  Executive Condominium       19
#
#       type_of_area                             tenure  nett_price  \
# 99951       Strata  99 yrs lease commencing from 2010         NaN
# 99769       Strata  99 yrs lease commencing from 1997         NaN
#
#                    project           street market_segment            x  \
# 99951  ESPARINA RESIDENCES  COMPASSVALE BOW            OCR  34460.87998
# 99769        THE RIVERVALE   RIVERVALE LINK            OCR  35185.81787
#
#                  y
# 99951  40428.28628
# 99769  40330.00568

# %%
df_ec['no_of_units'].unique()
# Out:
# array([1])

# %%
df_ec['type_of_area'].unique()
# Out:
# array(['Strata'], dtype=object)

# %%
columns_to_drop = ['no_of_units','type_of_area']
df_ec.drop(columns=columns_to_drop,inplace=True)

# %%
df_ec['tenure'].unique()
# Out:
# array(['99 yrs lease commencing from 1997',
#        '99 yrs lease commencing from 2011',
#        '99 yrs lease commencing from 2010',
#        '99 yrs lease commencing from 1996',
#        '99 yrs lease commencing from 2000',
#        '99 yrs lease commencing from 2003',
#        '99 yrs lease commencing from 2001',
#        '99 yrs lease commencing from 2004',
#        '99 yrs lease commencing from 2002',
#        '99 yrs lease commencing from 2012',
#        '99 yrs lease commencing from 2013',
#        '99 yrs lease commencing from 2015',
#        '99 yrs lease commencing from 2014',
#        '99 yrs lease commencing from 2016',
#        '99 yrs lease commencing from 2018'], dtype=object)

# %%
df_ec['tenure_start'] = df_ec['tenure'].apply(lambda x: int(x.split(' ')[-1]))
print(df_ec['tenure_start'].unique())
df_ec['building_age'] = df_ec['contract_date'].dt.year - df_ec['tenure_start']
df_ec.head()
# Out:
# [1997 2011 2010 1996 2000 2003 2001 2004 2002 2012 2013 2015 2014 2016
#  2018]
#                                           id   area floor_range contract_date  \
# 126465  70233109-b115-470a-8598-c6ac7fac4400  120.0       11-15    2019-09-01
# 124157  836f7655-2f22-4c9f-8461-e09aa66dbd46   90.0       11-15    2019-09-01
# 66715   41135f16-58a7-45a5-8c51-b273d7659119  129.0       11-15    2019-09-01
# 124163  0c5e0bef-b54a-4ed2-8b89-c5ac77deab25   98.0       06-10    2019-09-01
# 124166  4c3d88bb-2975-4ebf-b221-5efb82e2f45b   98.0       01-05    2019-09-01
#
#        type_of_sale     price          property_type district  \
# 126465            3  853000.0  Executive Condominium       23
# 124157            3  875000.0  Executive Condominium       23
# 66715             3  950000.0  Executive Condominium       18
# 124163            3  825000.0  Executive Condominium       23
# 124166            3  890000.0  Executive Condominium       23
#
#                                    tenure  nett_price             project  \
# 126465  99 yrs lease commencing from 1997         NaN       YEW MEI GREEN
# 124157  99 yrs lease commencing from 2011         NaN  BLOSSOM RESIDENCES
# 66715   99 yrs lease commencing from 1997         NaN            PINEVALE
# 124163  99 yrs lease commencing from 2011         NaN  BLOSSOM RESIDENCES
# 124166  99 yrs lease commencing from 2011         NaN  BLOSSOM RESIDENCES
#
#                        street market_segment            x            y  \
# 126465  CHOA CHU KANG NORTH 6            OCR  18819.03588  41984.19449
# 124157             SEGAR ROAD            OCR  20983.51444  41310.75604
# 66715      TAMPINES STREET 73            OCR  39121.60695  37836.26604
# 124163             SEGAR ROAD            OCR  20983.51444  41310.75604
# 124166             SEGAR ROAD            OCR  20983.51444  41310.75604
#
#         tenure_start  building_age
# 126465          1997            22
# 124157          2011             8
# 66715           1997            22
# 124163          2011             8
# 124166          2011             8

# %%
#
