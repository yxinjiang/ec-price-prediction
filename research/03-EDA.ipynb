# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
import requests
import json
from mlProject.utils.ura_token import ura_token
from pandas import json_normalize
import psycopg2
import uuid
import pandas.io.sql as psql

# %%
from datetime import datetime
import json
from dotenv import load_dotenv
import os

# Load environment variables from the .env file (if present)
# Out:
# True

# %%
def get_dataframe_from_sql(table_name: str, conn_params: dict):
    connection = psycopg2.connect(**conn_params)
    cursor = connection.cursor()
    df = psql.read_sql(f"Select * from {table_name}", connection)
    return df

# %%
# Connect to PostgreSQL
load_dotenv()

database = os.getenv('database')
dbuser = os.getenv('dbuser')
dbpassword = os.getenv('dbpassword')

conn_params = {
    "host":"localhost",
    "database":database,
    "user":dbuser,
    "password":dbpassword

}

table_name = "propertypricetable"
df_fetch = get_dataframe_from_sql(table_name, conn_params)
df_fetch.head()
# Out:
#                                      id   area floor_range  no_of_units  \
# 0  bd8e964b-8b01-45ca-9cd5-d5810b9588d4  159.3           -            1
# 1  54d728f7-df61-42fc-ab22-f7ef08bbe7dd  186.0           -            1
# 2  b5190668-75e4-49e5-9fc4-81b504d8d35a  257.0           -            1
# 3  d46fe197-3c71-4278-83ed-51bb2816db8e  524.3           -            1
# 4  a825db95-5239-4bd9-8e19-f21bb265d42b  308.0           -            1
#
#   contract_date type_of_sale      price   property_type district type_of_area  \
# 0    2020-03-01            3  2630000.0         Terrace       05         Land
# 1    2021-03-01            3  1880000.0  Strata Terrace       05       Strata
# 2    2022-05-01            3  4600000.0         Terrace       05         Land
# 3    2020-02-01            3  5500000.0   Semi-detached       05         Land
# 4    2021-09-01            3  5200000.0   Semi-detached       05         Land
#
#      tenure  nett_price                     project             street  \
# 0  Freehold         NaN  LANDED HOUSING DEVELOPMENT  NEO PEE TECK LANE
# 1  Freehold         NaN  LANDED HOUSING DEVELOPMENT  NEO PEE TECK LANE
# 2  Freehold         NaN  LANDED HOUSING DEVELOPMENT  NEO PEE TECK LANE
# 3  Freehold         NaN  LANDED HOUSING DEVELOPMENT       ZEHNDER ROAD
# 4  Freehold         NaN  LANDED HOUSING DEVELOPMENT       ZEHNDER ROAD
#
#   market_segment             x             y
# 0            RCR  20914.198897  30589.107079
# 1            RCR  20914.198897  30589.107079
# 2            RCR  20914.198897  30589.107079
# 3            RCR           NaN           NaN
# 4            RCR           NaN           NaN

# %% [markdown]
# connection = psycopg2.connect(**conn_params)
# cursor = connection.cursor()
# cursor.execute("""SELECT table_name FROM information_schema.tables
#        WHERE table_schema = 'public'""")
# for table in cursor.fetchall():
#     print(table)
# cursor.close()
# connection.close()

# %%
df_fetch.dtypes.to_dict()
# Out:
# {'id': dtype('O'),
#  'area': dtype('float64'),
#  'floor_range': dtype('O'),
#  'no_of_units': dtype('int64'),
#  'contract_date': dtype('<M8[ns]'),
#  'type_of_sale': dtype('O'),
#  'price': dtype('float64'),
#  'property_type': dtype('O'),
#  'district': dtype('O'),
#  'type_of_area': dtype('O'),
#  'tenure': dtype('O'),
#  'nett_price': dtype('float64'),
#  'project': dtype('O'),
#  'street': dtype('O'),
#  'market_segment': dtype('O'),
#  'x': dtype('float64'),
#  'y': dtype('float64')}

# %%
df_fetch.to_csv(f'../data/raw/{table_name}.csv',index=False)

# %%
df_ec = df_fetch.loc[(df_fetch['property_type']=='Executive Condominium')].sort_values(by=['contract_date'])#&(df_fetch['type_of_sale']=='3')

# %%
df_ec.head(2)
# Out:
#                                          id   area floor_range  no_of_units  \
# 77162  870ae034-8a35-475f-9426-b2f37dada9e6  140.0       06-10            1
# 77161  6568a8d9-b589-4e9a-aef8-2223b805644a  127.0       06-10            1
#
#       contract_date type_of_sale      price          property_type district  \
# 77162    2019-08-01            1  1636800.0  Executive Condominium       19
# 77161    2019-08-01            1  1420800.0  Executive Condominium       19
#
#       type_of_area                             tenure  nett_price  \
# 77162       Strata  99 yrs lease commencing from 2018         NaN
# 77161       Strata  99 yrs lease commencing from 2018         NaN
#
#               project       street market_segment           x            y
# 77162  PIERMONT GRAND  SUMANG WALK            OCR  35168.0772  43541.40613
# 77161  PIERMONT GRAND  SUMANG WALK            OCR  35168.0772  43541.40613

# %%
df_fetch.floor_range.unique()
# Out:
# array(['-', '01-05', '06-10', '21-25', '31-35', '41-45', '16-20', '36-40',
#        '26-30', '11-15', '56-60', '46-50', '51-55', 'B1-B5', '61-65',
#        '66-70', '71-75'], dtype=object)

# %%
df_ec.hist(bins=50, figsize=(15, 15))
plt.show()

# %%
df_ec['type_of_area'].unique()
# Out:
# array(['Strata'], dtype=object)

# %%
df_ec['market_segment'].unique()
# Out:
# array(['OCR', 'RCR'], dtype=object)

# %%
def diff_month(d1, d2):
    return (d1.year - d2.year) * 12 + d1.month - d2.month

# %%
df_ec['tenure_start'] = df_ec['tenure'].apply(lambda x: int(x.split(' ')[-1]))
#print(df_ec['tenure_start'].unique())
df_ec['year_after_lease_com'] = df_ec['contract_date'].dt.year - df_ec['tenure_start']
df_ec['year_after_lease_com'] = df_ec['year_after_lease_com'].astype(int)
df_ec['contract_month'] = df_ec['contract_date'].dt.month
#df_ec['contract_date_month'] = df_ec['contract_date'].apply(lambda x: diff_month(x, datetime(2019,8,1)))
floor_range = sorted(df_ec['floor_range'].unique())
level = range(1,len(floor_range)+1)
map_dict = dict(zip(floor_range, level))
df_ec.replace({"floor_range": map_dict},inplace=True)

df_ec['price_sqft'] = df_ec['price']/df_ec['area']
df_ec['district'] = df_ec['district'].astype(int)
df_ec.head()
# Out:
#                                          id   area  floor_range  no_of_units  \
# 77162  870ae034-8a35-475f-9426-b2f37dada9e6  140.0            2            1
# 77161  6568a8d9-b589-4e9a-aef8-2223b805644a  127.0            2            1
# 77207  dbf5b06f-139a-4b8a-b49f-ccd729423c1a   92.0            1            1
# 77132  1017602d-13c5-436e-867c-c720d7d87ab3   97.0            3            1
# 77138  35017259-9b61-4dcc-ab82-7f762ce44a49   90.0            2            1
#
#       contract_date type_of_sale      price          property_type  district  \
# 77162    2019-08-01            1  1636800.0  Executive Condominium        19
# 77161    2019-08-01            1  1420800.0  Executive Condominium        19
# 77207    2019-08-01            1  1028000.0  Executive Condominium        19
# 77132    2019-08-01            1  1072000.0  Executive Condominium        19
# 77138    2019-08-01            1  1051500.0  Executive Condominium        19
#
#       type_of_area  ... nett_price         project       street  \
# 77162       Strata  ...        NaN  PIERMONT GRAND  SUMANG WALK
# 77161       Strata  ...        NaN  PIERMONT GRAND  SUMANG WALK
# 77207       Strata  ...        NaN  PIERMONT GRAND  SUMANG WALK
# 77132       Strata  ...        NaN  PIERMONT GRAND  SUMANG WALK
# 77138       Strata  ...        NaN  PIERMONT GRAND  SUMANG WALK
#
#       market_segment           x            y  tenure_start  \
# 77162            OCR  35168.0772  43541.40613          2018
# 77161            OCR  35168.0772  43541.40613          2018
# 77207            OCR  35168.0772  43541.40613          2018
# 77132            OCR  35168.0772  43541.40613          2018
# 77138            OCR  35168.0772  43541.40613          2018
#
#        year_after_lease_com  contract_month    price_sqft
# 77162                     1               8  11691.428571
# 77161                     1               8  11187.401575
# 77207                     1               8  11173.913043
# 77132                     1               8  11051.546392
# 77138                     1               8  11683.333333
#
# [5 rows x 21 columns]

# %%
columns_to_drop = ['no_of_units','type_of_area','nett_price','property_type','id','tenure_start']#,'type_of_sale'
df_ec.drop(columns=columns_to_drop,inplace=True)

# %%
#
print([feature for feature in df_ec.columns if df_ec[feature].dtype != 'O'])
numeric_features = ['price','area','price_sqft','contract_date','floor_range','district','x','y','year_after_lease_com','contract_month']
# Out:
# ['area', 'floor_range', 'contract_date', 'price', 'district', 'x', 'y', 'year_after_lease_com', 'contract_month', 'price_sqft']

# %% [markdown]
# #### Investigate type of sale according to years after commencement

# %%
col = 'price'

fig, ax = plt.subplots(1, 2, figsize=(10,5))
fig.suptitle('Distribution of Numerical Features By market segment', color='#3C3744',fontsize=13, fontweight='bold', ha='center') 
sns.boxplot(data=df_ec, x='market_segment', y=col, ax=ax[0])
ax[0].set_title(f'Boxplot of {col}', fontsize=12)
sns.histplot(data=df_ec, x=col, hue='market_segment', bins=20, kde=True, multiple='stack', ax=ax[1])
ax[1].set_title(f'Histogram of {col}', fontsize=14)
fig.tight_layout()
fig.subplots_adjust(top=0.90)
# plt.savefig('images/multivariate_num.png')

# %%
df_ec_year_after_lease_com = df_ec['year_after_lease_com'].value_counts().sort_index()
df_ec_year_after_lease_com.plot.bar()
# Out:
# <Axes: xlabel='year_after_lease_com'>

# %%
df_ec.loc[df_ec['type_of_sale']=='3','year_after_lease_com'].value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='year_after_lease_com'>

# %%
df_ec.loc[df_ec['type_of_sale']!='3','year_after_lease_com'].value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='year_after_lease_com'>

# %%
df_ec_year_after_lease_com.to_frame().reset_index().describe()
# Out:
#        year_after_lease_com        count
# count             28.000000    28.000000
# mean              14.500000   531.071429
# std                8.225975   817.912289
# min                1.000000     4.000000
# 25%                7.750000    69.250000
# 50%               14.500000   156.500000
# 75%               21.250000   515.000000
# max               28.000000  2934.000000

# %%
fig, ax = plt.subplots()
ax.scatter(x = df_ec['area'], y = df_ec['price'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('Area', fontsize=13)
plt.show()

# %% [markdown]
# #### We can see one transaction with very large area and high price

# %%
from scipy.stats import norm, skew #for some statistics
from scipy import stats

# %%
def plot_distribution_qq_plot(df_ec,col):
    #We use the numpy fuction log1p which  applies log(1+x) to all elements of the column
    fig,ax = plt.subplots(2,2,figsize=(12,8))

    sns.distplot(df_ec[col] , fit=norm,ax=ax[0,0]);

    # Get the fitted parameters used by the function
    (mu, sigma) = norm.fit(df_ec[col])
    print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

    #Now plot the distribution
    plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
                loc='best')
    plt.ylabel('Frequency')
    plt.title(f'{col} distribution')

    #Get also the QQ-plot
    #fig = plt.figure()
    res = stats.probplot(df_ec[col], plot=ax[0,1])

    df_ec[f"{col}_log1p"] = np.log1p(df_ec[col])

    sns.distplot(df_ec[f'{col}_log1p'] , fit=norm,ax=ax[1,0]);

    # Get the fitted parameters used by the function
    (mu, sigma) = norm.fit(df_ec[f'{col}_log1p'])
    print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

    #Now plot the distribution
    plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
                loc='best')
    plt.ylabel('Frequency')
    plt.title(f'{col} distribution')

    #Get also the QQ-plot
    #fig = plt.figure()
    res = stats.probplot(df_ec[f'{col}_log1p'], plot=ax[1,1])
    plt.show()

plot_distribution_qq_plot(df_ec,'price')
plot_distribution_qq_plot(df_ec,'area')
plot_distribution_qq_plot(df_ec,'price_sqft')
# Out:
#  mu = 1271758.24 and sigma = 293415.12
#
#
#  mu = 14.03 and sigma = 0.23
#  mu = 104.21 and sigma = 22.18
#
#
#  mu = 4.64 and sigma = 0.20
#  mu = 12363.12 and sigma = 2270.25
#
#
#  mu = 9.40 and sigma = 0.20

# %% [markdown]
# #### The target variable is right skewed. As (linear) models love normally distributed data , we need to transform this variable and make it more normally distributed.

# %% [markdown]
# #### The skew seems now corrected and the data appears more normally distributed.

# %%
df_ec["price_log1p"] = np.log1p(df_ec['price'])

# %% [markdown]
# ### Missing Data

# %%
all_data_na = (df_ec.isnull().sum() / len(df_ec)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data
# Out:
#    Missing Ratio
# x        9.26698
# y        9.26698

# %%
df_null = df_ec[df_ec.isnull().any(axis=1)]
df_null['type_of_sale'].unique()
# Out:
# array(['1'], dtype=object)

# %%
df_ec_num = df_ec[numeric_features]
pear_corr=df_ec_num.corr(method='pearson')
display(pear_corr['price'].sort_values(ascending=False).to_frame().style.background_gradient(cmap='Greens', axis=0))
display(pear_corr.style.background_gradient(cmap='Greens', axis=0))
# Out:
# <style type="text/css">
# #T_4cf2e_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_4cf2e_row1_col0 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_4cf2e_row2_col0 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_4cf2e_row3_col0 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_4cf2e_row4_col0 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_4cf2e_row5_col0 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_4cf2e_row6_col0 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_4cf2e_row7_col0 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_4cf2e_row8_col0 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_4cf2e_row9_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_4cf2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4cf2e_level0_col0" class="col_heading level0 col0" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4cf2e_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_4cf2e_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2e_level0_row1" class="row_heading level0 row1" >area</th>
#       <td id="T_4cf2e_row1_col0" class="data row1 col0" >0.573784</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2e_level0_row2" class="row_heading level0 row2" >price_sqft</th>
#       <td id="T_4cf2e_row2_col0" class="data row2 col0" >0.560798</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2e_level0_row3" class="row_heading level0 row3" >contract_date</th>
#       <td id="T_4cf2e_row3_col0" class="data row3 col0" >0.470905</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2e_level0_row4" class="row_heading level0 row4" >x</th>
#       <td id="T_4cf2e_row4_col0" class="data row4 col0" >0.144020</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2e_level0_row5" class="row_heading level0 row5" >floor_range</th>
#       <td id="T_4cf2e_row5_col0" class="data row5 col0" >0.098998</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2e_level0_row6" class="row_heading level0 row6" >contract_month</th>
#       <td id="T_4cf2e_row6_col0" class="data row6 col0" >0.017846</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2e_level0_row7" class="row_heading level0 row7" >district</th>
#       <td id="T_4cf2e_row7_col0" class="data row7 col0" >-0.034491</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2e_level0_row8" class="row_heading level0 row8" >y</th>
#       <td id="T_4cf2e_row8_col0" class="data row8 col0" >-0.070296</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2e_level0_row9" class="row_heading level0 row9" >year_after_lease_com</th>
#       <td id="T_4cf2e_row9_col0" class="data row9 col0" >-0.249420</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2f099_row0_col0, #T_2f099_row1_col1, #T_2f099_row2_col2, #T_2f099_row3_col3, #T_2f099_row4_col4, #T_2f099_row5_col5, #T_2f099_row6_col6, #T_2f099_row7_col7, #T_2f099_row8_col8, #T_2f099_row9_col9 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2f099_row0_col1, #T_2f099_row2_col3 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_2f099_row0_col2 {
#   background-color: #29914a;
#   color: #f1f1f1;
# }
# #T_2f099_row0_col3 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_2f099_row0_col4 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_2f099_row0_col5 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_2f099_row0_col6 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_2f099_row0_col7, #T_2f099_row5_col1 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_2f099_row0_col8, #T_2f099_row3_col1, #T_2f099_row9_col0 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_2f099_row0_col9 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_2f099_row1_col0 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_2f099_row1_col2 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_2f099_row1_col3 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_2f099_row1_col4, #T_2f099_row1_col7 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_2f099_row1_col5 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_2f099_row1_col6, #T_2f099_row9_col6 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_2f099_row1_col8 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_2f099_row1_col9, #T_2f099_row3_col9 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_2f099_row2_col0 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_2f099_row2_col1, #T_2f099_row2_col8, #T_2f099_row2_col9, #T_2f099_row5_col6, #T_2f099_row6_col3, #T_2f099_row6_col5, #T_2f099_row6_col7, #T_2f099_row7_col4, #T_2f099_row7_col9, #T_2f099_row8_col0, #T_2f099_row8_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2f099_row2_col4, #T_2f099_row7_col1 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_2f099_row2_col5 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_2f099_row2_col6 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_2f099_row2_col7 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_2f099_row3_col0 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_2f099_row3_col2 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_2f099_row3_col4 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_2f099_row3_col5 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_2f099_row3_col6, #T_2f099_row8_col5 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_2f099_row3_col7 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_2f099_row3_col8, #T_2f099_row4_col2 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_2f099_row4_col0 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_2f099_row4_col1 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_2f099_row4_col3 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_2f099_row4_col5 {
#   background-color: #aadda4;
#   color: #000000;
# }
# #T_2f099_row4_col6 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_2f099_row4_col7, #T_2f099_row9_col4 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_2f099_row4_col8 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_2f099_row4_col9, #T_2f099_row6_col9 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_2f099_row5_col0 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_2f099_row5_col2 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_2f099_row5_col3, #T_2f099_row8_col6 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_2f099_row5_col4 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_2f099_row5_col7 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_2f099_row5_col8 {
#   background-color: #bde5b6;
#   color: #000000;
# }
# #T_2f099_row5_col9 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_2f099_row6_col0 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_2f099_row6_col1, #T_2f099_row7_col8 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_2f099_row6_col2 {
#   background-color: #8bcf89;
#   color: #000000;
# }
# #T_2f099_row6_col4 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_2f099_row6_col8 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_2f099_row7_col0 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_2f099_row7_col2 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_2f099_row7_col3 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_2f099_row7_col5 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_2f099_row7_col6 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_2f099_row8_col1 {
#   background-color: #7ac77b;
#   color: #000000;
# }
# #T_2f099_row8_col3 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_2f099_row8_col4 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_2f099_row8_col7 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_2f099_row8_col9 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_2f099_row9_col1 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_2f099_row9_col2 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_2f099_row9_col3 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_2f099_row9_col5 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_2f099_row9_col7 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_2f099_row9_col8 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# </style>
# <table id="T_2f099">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f099_level0_col0" class="col_heading level0 col0" >price</th>
#       <th id="T_2f099_level0_col1" class="col_heading level0 col1" >area</th>
#       <th id="T_2f099_level0_col2" class="col_heading level0 col2" >price_sqft</th>
#       <th id="T_2f099_level0_col3" class="col_heading level0 col3" >contract_date</th>
#       <th id="T_2f099_level0_col4" class="col_heading level0 col4" >floor_range</th>
#       <th id="T_2f099_level0_col5" class="col_heading level0 col5" >district</th>
#       <th id="T_2f099_level0_col6" class="col_heading level0 col6" >x</th>
#       <th id="T_2f099_level0_col7" class="col_heading level0 col7" >y</th>
#       <th id="T_2f099_level0_col8" class="col_heading level0 col8" >year_after_lease_com</th>
#       <th id="T_2f099_level0_col9" class="col_heading level0 col9" >contract_month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f099_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_2f099_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2f099_row0_col1" class="data row0 col1" >0.573784</td>
#       <td id="T_2f099_row0_col2" class="data row0 col2" >0.560798</td>
#       <td id="T_2f099_row0_col3" class="data row0 col3" >0.470905</td>
#       <td id="T_2f099_row0_col4" class="data row0 col4" >0.098998</td>
#       <td id="T_2f099_row0_col5" class="data row0 col5" >-0.034491</td>
#       <td id="T_2f099_row0_col6" class="data row0 col6" >0.144020</td>
#       <td id="T_2f099_row0_col7" class="data row0 col7" >-0.070296</td>
#       <td id="T_2f099_row0_col8" class="data row0 col8" >-0.249420</td>
#       <td id="T_2f099_row0_col9" class="data row0 col9" >0.017846</td>
#     </tr>
#     <tr>
#       <th id="T_2f099_level0_row1" class="row_heading level0 row1" >area</th>
#       <td id="T_2f099_row1_col0" class="data row1 col0" >0.573784</td>
#       <td id="T_2f099_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_2f099_row1_col2" class="data row1 col2" >-0.328658</td>
#       <td id="T_2f099_row1_col3" class="data row1 col3" >-0.045351</td>
#       <td id="T_2f099_row1_col4" class="data row1 col4" >0.062996</td>
#       <td id="T_2f099_row1_col5" class="data row1 col5" >-0.090438</td>
#       <td id="T_2f099_row1_col6" class="data row1 col6" >0.018060</td>
#       <td id="T_2f099_row1_col7" class="data row1 col7" >-0.079596</td>
#       <td id="T_2f099_row1_col8" class="data row1 col8" >0.312090</td>
#       <td id="T_2f099_row1_col9" class="data row1 col9" >0.038441</td>
#     </tr>
#     <tr>
#       <th id="T_2f099_level0_row2" class="ro

# %%
df_ec_resale = df_ec[df_ec['type_of_sale']=='3'].drop(columns=['type_of_sale'])
df_ec_num = df_ec_resale[numeric_features]
pear_corr=df_ec_num.corr(method='pearson')
display(pear_corr.style.background_gradient(cmap='Greens', axis=0))
display(pear_corr['price'].sort_values(ascending=False).to_frame().style.background_gradient(cmap='Greens', axis=0))
# Out:
# <style type="text/css">
# #T_d78a1_row0_col0, #T_d78a1_row1_col1, #T_d78a1_row2_col2, #T_d78a1_row3_col3, #T_d78a1_row4_col4, #T_d78a1_row5_col5, #T_d78a1_row6_col6, #T_d78a1_row7_col7, #T_d78a1_row8_col8, #T_d78a1_row9_col9 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_d78a1_row0_col1, #T_d78a1_row5_col7 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_d78a1_row0_col2 {
#   background-color: #369f54;
#   color: #f1f1f1;
# }
# #T_d78a1_row0_col3, #T_d78a1_row1_col8, #T_d78a1_row2_col0 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_d78a1_row0_col4, #T_d78a1_row4_col0 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_d78a1_row0_col5 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_d78a1_row0_col6 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# #T_d78a1_row0_col7 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_d78a1_row0_col8 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_d78a1_row0_col9, #T_d78a1_row1_col2 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_d78a1_row1_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_d78a1_row1_col3 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_d78a1_row1_col4 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_d78a1_row1_col5 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_d78a1_row1_col6 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_d78a1_row1_col7, #T_d78a1_row9_col4 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_d78a1_row1_col9, #T_d78a1_row3_col4, #T_d78a1_row5_col4 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_d78a1_row2_col1, #T_d78a1_row2_col8, #T_d78a1_row3_col9, #T_d78a1_row5_col6, #T_d78a1_row6_col3, #T_d78a1_row6_col5, #T_d78a1_row7_col4, #T_d78a1_row8_col0, #T_d78a1_row8_col2, #T_d78a1_row8_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_d78a1_row2_col3 {
#   background-color: #1f8742;
#   color: #f1f1f1;
# }
# #T_d78a1_row2_col4 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_d78a1_row2_col5, #T_d78a1_row9_col6 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_d78a1_row2_col6 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_d78a1_row2_col7 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_d78a1_row2_col9, #T_d78a1_row6_col4 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_d78a1_row3_col0 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_d78a1_row3_col1, #T_d78a1_row6_col0 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_d78a1_row3_col2 {
#   background-color: #107a37;
#   color: #f1f1f1;
# }
# #T_d78a1_row3_col5 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_d78a1_row3_col6 {
#   background-color: #bde5b6;
#   color: #000000;
# }
# #T_d78a1_row3_col7 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_d78a1_row3_col8 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_d78a1_row4_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_d78a1_row4_col2 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_d78a1_row4_col3 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_d78a1_row4_col5 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_d78a1_row4_col6, #T_d78a1_row4_col8, #T_d78a1_row6_col1, #T_d78a1_row8_col5 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_d78a1_row4_col7 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_d78a1_row4_col9 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_d78a1_row5_col0 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_d78a1_row5_col1, #T_d78a1_row7_col3 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_d78a1_row5_col2, #T_d78a1_row7_col2 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_d78a1_row5_col3, #T_d78a1_row6_col8, #T_d78a1_row7_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_d78a1_row5_col8 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_d78a1_row5_col9 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_d78a1_row6_col2 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_d78a1_row6_col7 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_d78a1_row6_col9, #T_d78a1_row9_col0 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_d78a1_row7_col0 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_d78a1_row7_col5 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_d78a1_row7_col6 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_d78a1_row7_col8 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_d78a1_row7_col9 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_d78a1_row8_col1 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_d78a1_row8_col3 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_d78a1_row8_col4 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_d78a1_row8_col6, #T_d78a1_row9_col8 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_d78a1_row8_col9 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_d78a1_row9_col1 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_d78a1_row9_col2 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_d78a1_row9_col3 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_d78a1_row9_col5 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_d78a1_row9_col7 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# </style>
# <table id="T_d78a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d78a1_level0_col0" class="col_heading level0 col0" >price</th>
#       <th id="T_d78a1_level0_col1" class="col_heading level0 col1" >area</th>
#       <th id="T_d78a1_level0_col2" class="col_heading level0 col2" >price_sqft</th>
#       <th id="T_d78a1_level0_col3" class="col_heading level0 col3" >contract_date</th>
#       <th id="T_d78a1_level0_col4" class="col_heading level0 col4" >floor_range</th>
#       <th id="T_d78a1_level0_col5" class="col_heading level0 col5" >district</th>
#       <th id="T_d78a1_level0_col6" class="col_heading level0 col6" >x</th>
#       <th id="T_d78a1_level0_col7" class="col_heading level0 col7" >y</th>
#       <th id="T_d78a1_level0_col8" class="col_heading level0 col8" >year_after_lease_com</th>
#       <th id="T_d78a1_level0_col9" class="col_heading level0 col9" >contract_month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d78a1_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_d78a1_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d78a1_row0_col1" class="data row0 col1" >0.561635</td>
#       <td id="T_d78a1_row0_col2" class="data row0 col2" >0.507549</td>
#       <td id="T_d78a1_row0_col3" class="data row0 col3" >0.503093</td>
#       <td id="T_d78a1_row0_col4" class="data row0 col4" >0.125169</td>
#       <td id="T_d78a1_row0_col5" class="data row0 col5" >-0.066256</td>
#       <td id="T_d78a1_row0_col6" class="data row0 col6" >0.090095</td>
#       <td id="T_d78a1_row0_col7" class="data row0 col7" >-0.022713</td>
#       <td id="T_d78a1_row0_col8" class="data row0 col8" >-0.127405</td>
#       <td id="T_d78a1_row0_col9" class="data row0 col9" >-0.014951</td>
#     </tr>
#     <tr>
#       <th id="T_d78a1_level0_row1" class="row_heading level0 row1" >area</th>
#       <td id="T_d78a1_row1_col0" class="data row1 col0" >0.561635</td>
#       <td id="T_d78a1_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d78a1_row1_col2" class="data row1 col2" >-0.397185</td>
#       <td id="T_d78a1_row1_col3" class="data row1 col3" >-0.125634</td>
#       <td id="T_d78a1_row1_col4" class="data row1 col4" >0.041179</td>
#       <td id="T_d78a1_row1_col5" class="data row1 col5" >-0.070110</td>
#       <td id="T_d78a1_row1_col6" class="data row1 col6" >0.035650</td>
#       <td id="T_d78a1_row1_col7" class="data row1 col7" >-0.042520</td>
#       <td id="T_d78a1_row1_col8" class="data row1 col8" >0.352277</td>
#       <td id="T_d78a1_row1_col9" class="data row1 col9" >0.031909</td>
#     </tr>
#     <tr>
#       <th id="T_d78a1_level0_row2" class="row_heading level0 row2" >price_sqft</th>
#       <td id="T_d78a1_row2_col0" class="data row2 col0" >0.507549</td>
#       <td id="T_d78a1_row2_col1" class="data row2 col1" >-0.397185</td>
#       <td id="T_d78a1_row2_col2" class="data row2 col2" >1.000000<
# <style type="text/css">
# #T_e2ced_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e2ced_row1_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_e2ced_row2_col0 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_e2ced_row3_col0 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_e2ced_row4_col0 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_e2ced_row5_col0 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_e2ced_row6_col0 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_e2ced_row7_col0 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_e2ced_row8_col0 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_e2ced_row9_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_e2ced">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2ced_level0_col0" class="col_heading level0 col0" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2ced_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_e2ced_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e2ced_level0_row1" class="row_heading level0 row1" >area</th>
#       <td id="T_e2ced_row1_col0" class="data row1 col0" >0.561635</td>
#     </tr>
#     <tr>
#       <th id="T_e2ced_level0_row2" class="row_heading level0 row2" >price_sqft</th>
#       <td id="T_e2ced_row2_col0" class="data row2 col0" >0.507549</td>
#     </tr>
#     <tr>
#       <th id="T_e2ced_level0_row3" class="row_heading level0 row3" >contract_date</th>
#       <td id="T_e2ced_row3_col0" class="data row3 col0" >0.503093</td>
#     </tr>
#     <tr>
#       <th id="T_e2ced_level0_row4" class="row_heading level0 row4" >floor_range</th>
#       <td id="T_e2ced_row4_col0" class="data row4 col0" >0.125169</td>
#     </tr>
#     <tr>
#       <th id="T_e2ced_level0_row5" class="row_heading level0 row5" >x</th>
#       <td id="T_e2ced_row5_col0" class="data row5 col0" >0.090095</td>
#     </tr>
#     <tr>
#       <th id="T_e2ced_level0_row6" class="row_heading level0 row6" >contract_month</th>
#       <td id="T_e2ced_row6_col0" class="data row6 col0" >-0.014951</td>
#     </tr>
#     <tr>
#       <th id="T_e2ced_level0_row7" class="row_heading level0 row7" >y</th>
#       <td id="T_e2ced_row7_col0" class="data row7 col0" >-0.022713</td>
#     </tr>
#     <tr>
#       <th id="T_e2ced_level0_row8" class="row_heading level0 row8" >district</th>
#       <td id="T_e2ced_row8_col0" class="data row8 col0" >-0.066256</td>
#     </tr>
#     <tr>
#       <th id="T_e2ced_level0_row9" class="row_heading level0 row9" >year_after_lease_com</th>
#       <td id="T_e2ced_row9_col0" class="data row9 col0" >-0.127405</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_ec['district'].value_counts()
# Out:
# district
# 19    4048
# 27    2917
# 18    2777
# 23    2070
# 25     942
# 28     922
# 24     639
# 22     461
# 20      94
# Name: count, dtype: int64

# %%
fig, ax1 = plt.subplots(figsize=(16, 6))
#ax2 = ax1.twinx()
palette = sns.color_palette("flare", as_cmap=True)
plt.title('Price vs Date', fontdict={'fontsize': 15}), plt.xlabel('Years'), plt.ylabel('House Price')
sns.lineplot(data=df_ec,x='contract_date', y='price',ax=ax1)
# Out:
# <Axes: title={'center': 'Price vs Date'}, xlabel='Years', ylabel='House Price'>

# %%
fig, ax = plt.subplots(figsize=(20, 6))
g = ax.scatter(df_ec['contract_date'],df_ec['price'], c=df_ec['area'], cmap=plt.get_cmap("jet"), alpha=0.7)
fig.colorbar(g)

# %%
fig, ax = plt.subplots(figsize=(20, 6))
g = ax.scatter(df_ec['contract_date'],df_ec['price_sqft'], c=df_ec['year_after_lease_com'], cmap=plt.get_cmap("jet"), alpha=0.7)
fig.colorbar(g)

# %%
fig, ax = plt.subplots(figsize=(20, 6))
g = ax.scatter(df_ec_resale['contract_date'],df_ec_resale['price_sqft'], c=df_ec_resale['year_after_lease_com'], cmap=plt.get_cmap("jet"), alpha=0.7)
fig.colorbar(g)

# %% [markdown]
# fig, ax2 = plt.subplots(figsize=(16, 6))
# amount_by_date = df_ec['contract_date'].value_counts().to_frame().reset_index().sort_values(by=['contract_date'])
# plt.title('Sale Amount vs Date', fontdict={'fontsize': 15}), plt.xlabel('Years'), plt.ylabel('House Price')
# sns.lineplot(data=amount_by_date,x='contract_date', y='count', label='House Price',ax=ax2)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,6))
df_ec.plot(kind="scatter", x="x", y="y", alpha=0.4,
            s=df_ec["area"], label="area",
            c="price", cmap=plt.get_cmap("jet"), colorbar=True,ax=ax)
plt.legend()

# %% [markdown]
# import requests
#
# load_dotenv()
# onemap_token = os.getenv('onemap_token')
# df_projec_null = pd.DataFrame()
# for name in df_null['project'].unique():
#
#     new_name = name.replace(' ','%20')
#     url = f"https://www.onemap.gov.sg/api/common/elastic/search?searchVal={new_name}&returnGeom=Y&getAddrDetails=Y&pageNum=1"
#     headers = {"Authorization": onemap_token}
#     response = requests.request("GET", url, headers=headers)
#
#     results = response.json()['results']
#     print(results[0])
#     df_ec.loc[df_ec['project']==name,'x'] = results[0]['X']
#     df_ec.loc[df_ec['project']==name,'y'] = results[0]['Y']

# %%
from sklearn.preprocessing import KBinsDiscretizer
n_bins = 5
enc = KBinsDiscretizer(n_bins=n_bins, encode="ordinal", strategy='quantile')#'uniform', 'kmeans', 'quantile'
df_ec['area_bin'] = enc.fit_transform(df_ec['area'].values.reshape(-1,1)).reshape(-1,)
df_ec['area_bin'].hist(bins=n_bins, figsize=(12, 5))
plt.show()

# %%
numeric_features = ['price','area','area_bin','price_sqft','contract_date','floor_range','district','x','y','year_after_lease_com','contract_month']
df_ec_resale = df_ec[df_ec['type_of_sale']=='3'].drop(columns=['type_of_sale'])
df_ec_num = df_ec_resale[numeric_features]
pear_corr=df_ec_num.corr(method='pearson')
display(pear_corr.style.background_gradient(cmap='Greens', axis=0))
display(pear_corr['price'].sort_values(ascending=False).to_frame().style.background_gradient(cmap='Greens', axis=0))
# Out:
# <style type="text/css">
# #T_78495_row0_col0, #T_78495_row1_col1, #T_78495_row2_col2, #T_78495_row3_col3, #T_78495_row4_col4, #T_78495_row5_col5, #T_78495_row6_col6, #T_78495_row7_col7, #T_78495_row8_col8, #T_78495_row9_col9, #T_78495_row10_col10 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_78495_row0_col1, #T_78495_row6_col8 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_78495_row0_col2, #T_78495_row1_col0, #T_78495_row2_col9 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_78495_row0_col3 {
#   background-color: #369f54;
#   color: #f1f1f1;
# }
# #T_78495_row0_col4, #T_78495_row1_col9, #T_78495_row3_col0 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_78495_row0_col5, #T_78495_row5_col0 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_78495_row0_col6 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_78495_row0_col7 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# #T_78495_row0_col8 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_78495_row0_col9, #T_78495_row5_col2 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_78495_row0_col10, #T_78495_row1_col3 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_78495_row1_col2 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_78495_row1_col4 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_78495_row1_col5 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_78495_row1_col6 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_78495_row1_col7 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_78495_row1_col8, #T_78495_row10_col5 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_78495_row1_col10, #T_78495_row2_col8, #T_78495_row4_col5, #T_78495_row6_col5 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_78495_row2_col0 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_78495_row2_col1 {
#   background-color: #05712f;
#   color: #f1f1f1;
# }
# #T_78495_row2_col3, #T_78495_row2_col5, #T_78495_row9_col5 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_78495_row2_col4, #T_78495_row9_col10 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_78495_row2_col6, #T_78495_row5_col7, #T_78495_row5_col9, #T_78495_row7_col1, #T_78495_row9_col6 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_78495_row2_col7 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_78495_row2_col10, #T_78495_row7_col10, #T_78495_row10_col0 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_78495_row3_col1, #T_78495_row3_col2, #T_78495_row3_col9, #T_78495_row4_col10, #T_78495_row6_col7, #T_78495_row7_col4, #T_78495_row7_col6, #T_78495_row8_col5, #T_78495_row9_col0, #T_78495_row9_col3, #T_78495_row9_col8 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_78495_row3_col4 {
#   background-color: #1f8742;
#   color: #f1f1f1;
# }
# #T_78495_row3_col5, #T_78495_row8_col2 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_78495_row3_col6, #T_78495_row10_col7 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_78495_row3_col7 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_78495_row3_col8 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_78495_row3_col10, #T_78495_row7_col5 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_78495_row4_col0 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_78495_row4_col1, #T_78495_row4_col2, #T_78495_row6_col2, #T_78495_row7_col0 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_78495_row4_col3 {
#   background-color: #107a37;
#   color: #f1f1f1;
# }
# #T_78495_row4_col6 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_78495_row4_col7, #T_78495_row10_col2 {
#   background-color: #bde5b6;
#   color: #000000;
# }
# #T_78495_row4_col8 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_78495_row4_col9 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_78495_row5_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_78495_row5_col3 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_78495_row5_col4 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_78495_row5_col6 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_78495_row5_col8 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_78495_row5_col10 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_78495_row6_col0 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_78495_row6_col1, #T_78495_row8_col4 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_78495_row6_col3, #T_78495_row8_col3 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_78495_row6_col4, #T_78495_row7_col9, #T_78495_row8_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_78495_row6_col9 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_78495_row6_col10 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_78495_row7_col2 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_78495_row7_col3 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_78495_row7_col8 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_78495_row8_col0 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_78495_row8_col6 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_78495_row8_col7 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_78495_row8_col9 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_78495_row8_col10 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_78495_row9_col1 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_78495_row9_col2 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_78495_row9_col4 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_78495_row9_col7, #T_78495_row10_col9 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_78495_row10_col1 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_78495_row10_col3 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_78495_row10_col4 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_78495_row10_col6 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_78495_row10_col8 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# </style>
# <table id="T_78495">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78495_level0_col0" class="col_heading level0 col0" >price</th>
#       <th id="T_78495_level0_col1" class="col_heading level0 col1" >area</th>
#       <th id="T_78495_level0_col2" class="col_heading level0 col2" >area_bin</th>
#       <th id="T_78495_level0_col3" class="col_heading level0 col3" >price_sqft</th>
#       <th id="T_78495_level0_col4" class="col_heading level0 col4" >contract_date</th>
#       <th id="T_78495_level0_col5" class="col_heading level0 col5" >floor_range</th>
#       <th id="T_78495_level0_col6" class="col_heading level0 col6" >district</th>
#       <th id="T_78495_level0_col7" class="col_heading level0 col7" >x</th>
#       <th id="T_78495_level0_col8" class="col_heading level0 col8" >y</th>
#       <th id="T_78495_level0_col9" class="col_heading level0 col9" >year_after_lease_com</th>
#       <th id="T_78495_level0_col10" class="col_heading level0 col10" >contract_month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78495_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_78495_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_78495_row0_col1" class="data row0 col1" >0.561635</td>
#       <td id="T_78495_row0_col2" class="data row0 col2" >0.471076</td>
#       <td id="T_78495_row0_col3" class="data row0 col3" >0.507549</td>
#       <td id="T_78495_row0_col4" class="data row0 col4" >0.503093</td>
#       <td id="T_78495_row0_col5" class="data row0 col5" >0.125169</td>
#       <td id="T_78495_row0_col6" class="data row0 col6" >-0.066256</td>
#       <td id="T_78495_row0_col7" class="data row0 col7" >0.090095</td>
#       <td id="T_78495_row0_col8" class="data row0 col8" >-0.022713</td>
#       <td id="T_78495_row0_col9" class="data row0 col9" >-0.127405</td>
#       <td id="T_78495_row0_col10" class="data row0 col10" >-0.014951</td>
#     </tr>
#     <tr>
#       <th id="T_78495_level0_row1" class="row_heading level0 row1" >area</th>
#       <td id="T_78495_row1_col0" class="data row1 col0" >0.561635</td>
#       <td id="T_78495_row1_col1" class="data row1 col1"
# <style type="text/css">
# #T_e6428_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e6428_row1_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_e6428_row2_col0 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_e6428_row3_col0 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_e6428_row4_col0 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_e6428_row5_col0 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_e6428_row6_col0 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_e6428_row7_col0 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_e6428_row8_col0 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_e6428_row9_col0 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_e6428_row10_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_e6428">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6428_level0_col0" class="col_heading level0 col0" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6428_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_e6428_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e6428_level0_row1" class="row_heading level0 row1" >area</th>
#       <td id="T_e6428_row1_col0" class="data row1 col0" >0.561635</td>
#     </tr>
#     <tr>
#       <th id="T_e6428_level0_row2" class="row_heading level0 row2" >price_sqft</th>
#       <td id="T_e6428_row2_col0" class="data row2 col0" >0.507549</td>
#     </tr>
#     <tr>
#       <th id="T_e6428_level0_row3" class="row_heading level0 row3" >contract_date</th>
#       <td id="T_e6428_row3_col0" class="data row3 col0" >0.503093</td>
#     </tr>
#     <tr>
#       <th id="T_e6428_level0_row4" class="row_heading level0 row4" >area_bin</th>
#       <td id="T_e6428_row4_col0" class="data row4 col0" >0.471076</td>
#     </tr>
#     <tr>
#       <th id="T_e6428_level0_row5" class="row_heading level0 row5" >floor_range</th>
#       <td id="T_e6428_row5_col0" class="data row5 col0" >0.125169</td>
#     </tr>
#     <tr>
#       <th id="T_e6428_level0_row6" class="row_heading level0 row6" >x</th>
#       <td id="T_e6428_row6_col0" class="data row6 col0" >0.090095</td>
#     </tr>
#     <tr>
#       <th id="T_e6428_level0_row7" class="row_heading level0 row7" >contract_month</th>
#       <td id="T_e6428_row7_col0" class="data row7 col0" >-0.014951</td>
#     </tr>
#     <tr>
#       <th id="T_e6428_level0_row8" class="row_heading level0 row8" >y</th>
#       <td id="T_e6428_row8_col0" class="data row8 col0" >-0.022713</td>
#     </tr>
#     <tr>
#       <th id="T_e6428_level0_row9" class="row_heading level0 row9" >district</th>
#       <td id="T_e6428_row9_col0" class="data row9 col0" >-0.066256</td>
#     </tr>
#     <tr>
#       <th id="T_e6428_level0_row10" class="row_heading level0 row10" >year_after_lease_com</th>
#       <td id="T_e6428_row10_col0" class="data row10 col0" >-0.127405</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_ec.columns.values
# Out:
# array(['area', 'floor_range', 'contract_date', 'type_of_sale', 'price',
#        'district', 'tenure', 'project', 'street', 'market_segment', 'x',
#        'y', 'year_after_lease_com', 'contract_month', 'price_sqft',
#        'price_log1p', 'area_log1p', 'price_sqft_log1p', 'area_bin'],
#       dtype=object)

# %%
drop_columns = ['area','tenure','price_log1p', 'area_log1p', 'price_sqft_log1p', 'price_sqft','']
#df_ec = df_ec.drop(columns=drop_columns)

# %%
target_cols = ['price','price_sqft']
project_group_cols = ['contract_date','floor_range','area_bin','project']
df_ec_project_mean = df_ec.groupby(project_group_cols)[target_cols].mean().reset_index()

district_group_cols = ['contract_date','floor_range','area_bin','district','year_after_lease_com']
df_ec_district_mean = df_ec.groupby(district_group_cols)[target_cols].mean().reset_index()

area_floor_year_group_cols = ['contract_date','floor_range','area_bin','year_after_lease_com']
area_floor_year_group_cols = df_ec.groupby(district_group_cols)[target_cols].mean().reset_index()

# %%
fig, ax = plt.subplots(figsize=(16, 6))
#ax2 = ax1.twinx()
palette = sns.color_palette("flare", as_cmap=True)
plt.title('Price vs Date', fontdict={'fontsize': 15}), plt.xlabel('Years'), plt.ylabel('House Price')
sns.lineplot(data=df_ec,x='contract_date', y='price',ax=ax,label='price', alpha=0.7)
sns.lineplot(data=df_ec_project_mean,x='contract_date', y='price',ax=ax,label='project mean price', alpha=0.7)
#g = ax1.scatter(df_ec['contract_date'],df_ec['price'], c=df_ec['area'], cmap=plt.get_cmap("jet"), alpha=0.7)
sns.lineplot(data=df_ec_district_mean,x='contract_date', y='price',ax=ax,label='district mean price', alpha=0.7)
sns.lineplot(data=area_floor_year_group_cols,x='contract_date', y='price',ax=ax,label='area_floor_year mean price', alpha=0.7)

#df_ec_district_mean.plot(x='contract_date', y='price', label='mean price', ax=ax)
#df_ec.plot(x='contract_date', y='price', label='price', ax=ax)
ax.legend()
plt.legend()
fig.colorbar(g)

# %%
#df_ec.drop(columns=['x','y'],inplace=True)

# %%
df_ec['area_bin'].unique()
# Out:
# array([3., 1., 2., 0.])

# %%
target = 'price'
for area in range(n_bins):
    fig, ax = plt.subplots(figsize=(16, 4))
    #ax2 = ax1.twinx()
    
    palette = sns.color_palette("flare", as_cmap=True)
    plt.title(f'{target} vs date', fontdict={'fontsize': 15}), plt.xlabel('Years'), plt.ylabel('House price sqft')
    #sns.lineplot(data=df_ec,x='contract_date', y=target,ax=ax,label=target)

    #for area in [1]:#range(5):
    sns.lineplot(data=df_ec[(df_ec['area_bin']==area)],x='contract_date', y=target,ax=ax,label=f'area_bin {area}: {target}')
    sns.lineplot(data=area_floor_year_group_cols[area_floor_year_group_cols['area_bin']==area],x='contract_date', y=target,ax=ax,label=f'area_bin {area}: project mean {target}')
    #g = ax1.scatter(df_ec['contract_date'],df_ec['price'], c=df_ec['area'], cmap=plt.get_cmap("jet"), alpha=0.7


    #df_ec_district_mean.plot(x='contract_date', y='price', label='mean price', ax=ax)
    #df_ec.plot(x='contract_date', y='price', label='price', ax=ax)
    ax.legend()
    plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 4))
#ax2 = ax1.twinx()
palette = sns.color_palette("flare", as_cmap=True)
plt.title(f'{target} vs date', fontdict={'fontsize': 15}), plt.xlabel('Years'), plt.ylabel('House price sqft')
sns.lineplot(data=df_ec,x='contract_date', y=target,ax=ax,label=target)

for area in range(5):
    #sns.lineplot(data=df_ec[df_ec['area_bin']==area],x='contract_date', y=target,ax=ax,label=f'area_bin {area}: {target}')
    sns.lineplot(data=area_floor_year_group_cols[area_floor_year_group_cols['area_bin']==area],x='contract_date', y=target,ax=ax,label=f'area_bin {area}: project mean {target}')
#g = ax1.scatter(df_ec['contract_date'],df_ec['price'], c=df_ec['area'], cmap=plt.get_cmap("jet"), alpha=0.7


#df_ec_district_mean.plot(x='contract_date', y='price', label='mean price', ax=ax)
#df_ec.plot(x='contract_date', y='price', label='price', ax=ax)
ax.legend()
plt.show()
